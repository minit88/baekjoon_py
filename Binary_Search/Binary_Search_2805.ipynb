# %% [markdown]
# <a href="https://colab.research.google.com/github/minit88/baekjoon_py/blob/main/Binary_Search/Binary_Search_2805.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 2805

n,m = map(int,input().split())
data =list(map(int,input().split()))
data.sort()

left = 0
right = data[-1]
final_count=-int(1e9)
final_result = -int(1e9) # 결과값을 저장

# 이진탐색 실행
while left <= right:
  result = 0
  mid = (left+right)//2
  for i in data:
    if i>mid:
      result += abs(i -mid)
  if result>=m:
    final_count = max(final_count,mid)
    left=mid+1 # 더 많이 자름
  elif result<m :
    right=mid-1
print(final_count)
# Out:
# 5 20
# 4 42 40 26 46
# 36
